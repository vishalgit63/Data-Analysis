# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalgit63/Data-Analysis/blob/main/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("House Price Prediction.csv")

# %%
df.head()
# Out:
#            id  number of bedrooms  living area  number of floors  \
# 0  6762810145                   5         3650               2.0
# 1  6762810635                   4         2920               1.5
# 2  6762810998                   5         2910               1.5
# 3  6762812605                   4         3310               2.0
# 4  6762812919                   3         2710               1.5
#
#    Area of the basement  Built Year  Renovation Year  \
# 0                   280        1921                0
# 1                  1010        1909                0
# 2                     0        1939                0
# 3                     0        2001                0
# 4                   830        1929                0
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# ...

# %%
df.shape
# Out:
# (14620, 10)

# %%
df.columns
# Out:
# Index(['id', 'number of bedrooms', 'living area', 'number of floors',
#        'Area of the basement', 'Built Year', 'Renovation Year',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         14620 non-null  int64
#  1   number of bedrooms         14620 non-null  int64
#  2   living area                14620 non-null  int64
#  3   number of floors           14620 non-null  float64
#  4   Area of the basement       14620 non-null  int64
#  5   Built Year                 14620 non-null  int64
#  6   Renovation Year            14620 non-null  int64
#  7   Number of schools nearby   14620 non-null  int64
#  8   Distance from the airport  14620 non-null  int64
#  9   Price                      14620 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 1.1 MB

# %%
import numpy as np
df
data = df.copy()
data
# Out:
#                id  number of bedrooms  living area  number of floors  \
# 0      6762810145                   5         3650               2.0
# 1      6762810635                   4         2920               1.5
# 2      6762810998                   5         2910               1.5
# 3      6762812605                   4         3310               2.0
# 4      6762812919                   3         2710               1.5
# ...           ...                 ...          ...               ...
# 14615  6762830250                   2         1556               1.0
# 14616  6762830339                   3         1680               1.5
# 14617  6762830618                   2         1070               1.0
# 14618  6762830709                   4         1030               1.0
# 14619  6762831463                   3          900               1.0
#
#        Area of the basement  Built Year  Renovation Year  \
# 0                       280        1921                0
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14615    False
# 14616    False
# 14617    False
# 14618    False
# 14619    False
# Length: 14620, dtype: bool

# %%
data = data.drop(columns=['id','Renovation Year','Number of schools nearby', 'Distance from the airport'])

# %%
display(data.head())
# Out:
#    number of bedrooms  living area  number of floors  Area of the basement  \
# 0                   5         3650               2.0                   280
# 1                   4         2920               1.5                  1010
# 2                   5         2910               1.5                     0
# 3                   4         3310               2.0                     0
# 4                   3         2710               1.5                   830
#
#    Built Year    Price
# 0        1921  2380000
# 1        1909  1400000
# 2        1939  1200000
# 3        2001   838000
# 4        1929   805000

# %%
data.count()
# Out:
# number of bedrooms      14620
# living area             14620
# number of floors        14620
# Area of the basement    14620
# Built Year              14620
# Price                   14620
# dtype: int64

# %%
data = data.query("Price > 0 ")

# %%
data.shape
# Out:
# (14620, 6)

# %%
data
# Out:
#        number of bedrooms  living area  number of floors  \
# 0                       5         3650               2.0
# 1                       4         2920               1.5
# 2                       5         2910               1.5
# 3                       4         3310               2.0
# 4                       3         2710               1.5
# ...                   ...          ...               ...
# 14615                   2         1556               1.0
# 14616                   3         1680               1.5
# 14617                   2         1070               1.0
# 14618                   4         1030               1.0
# 14619                   3          900               1.0
#
#        Area of the basement  Built Year    Price
# 0                       280        1921  2380000
# 1                      1010        1909  1400000
# 2                         0        1939  1200000
# 3                         0        2001   838000
# ...

# %% [markdown]
# ## Feature Label Seprations

# %% [markdown]
# * x = contains all columns except "Price" column
# * y = contains only "Price" column

# %%
x = data.drop(columns=['Price'])

# %%
y = data['Price']

# %% [markdown]
# # Train test Spiliting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
data.shape
# Out:
# (14620, 6)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((11696, 5), (2924, 5), (11696,), (2924,))

# %%
-
